# %% [markdown]
# <a href="https://colab.research.google.com/github/Hasib-EvnRiaz/Phi.-ai-ml-sem-1/blob/main/File_Handling_and_Exception_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## File Read

# %%
file = open("./sample_data/sample.txt","r")

content = file.read()

print(type(content))

file.close()
print(file.closed)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7145/2053239956.py in <cell line: 0>()
# ----> 1 file = open("./sample_data/sample.txt","r")
#       2
#       3 content = file.read()
#       4
#       5 print(type(content))
#
# FileNotFoundError: [Errno 2] No such file or directory: './sample_data/sample.txt'

# %%
file = open("./sample_data/sample.txt","r")

content = file.readlines()

content = list(map(str.strip,content))

filter_content = list(filter(lambda x : len(x)>=1,content))

print(filter_content)

# %%
with open("./sample_data/sample.txt","r") as file:
  content = file.readlines()
  print(content)

print(file.closed)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7145/2829579297.py in <cell line: 0>()
# ----> 1 with open("./sample_data/sample.txt","r") as file:
#       2   content = file.readlines()
#       3   print(content)
#       4
#       5 print(file.closed)
#
# FileNotFoundError: [Errno 2] No such file or directory: './sample_data/sample.txt'

# %%
with open("./sample_data/sample.txt","r") as file:
  for line in file:
    l = line.strip()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7145/2840462592.py in <cell line: 0>()
# ----> 1 with open("./sample_data/sample.txt","r") as file:
#       2   for line in file:
#       3     l = line.strip()
#
# FileNotFoundError: [Errno 2] No such file or directory: './sample_data/sample.txt'

# %% [markdown]
# ## File Write

# %%
# creating a new file and writing there
with open("./sample_data/test.txt","w") as file:

  file.write("Hello test file\n")
  file.write("How is learning going on ?")

# %%
# writing on a existing file
# it overwrites the file

with open("./sample_data/test.txt","w") as file:

  file.write("Second attempt\n")
  file.write("learning is going fast\n")

# %%
# No overwriting just append the text later
# append mode
with open("./sample_data/test.txt","a") as file:

  file.write("The learning of AI/ML is fun\n")
  file.write("I am enjoying the classes")

# %%
strings = ['hello','hi','good bye','what up']

with open("./sample_data/test2.txt","a") as file:

  file.writelines(strings)

# %%
with open("./sample_data/sample.txt","r") as file:
  print(file.tell()) # currently cursor koi ase
  print(file.read())
  print(file.tell())
  ## last index theke pora shuru korsi
  print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7145/2176718677.py in <cell line: 0>()
# ----> 1 with open("./sample_data/sample.txt","r") as file:
#       2   print(file.tell()) # currently cursor koi ase
#       3   print(file.read())
#       4   print(file.tell())
#       5   ## last index theke pora shuru korsi
#
# FileNotFoundError: [Errno 2] No such file or directory: './sample_data/sample.txt'

# %%
with open("./sample_data/sample.txt","r") as file:
  print(file.tell())
  print(file.read(5))
  print(file.tell())

  print(file.read())
  print(file.tell())

# %%
#seek

with open("./sample_data/sample.txt","r") as file:
  print(file.tell())

  print(file.read(5))

  print(file.tell())

  file.seek(0)
  print(file.tell())
  print(file.read(5))

# %% [markdown]
# ## Practice 1 :
#
# Get the text from sample.txt , and count the following
#
#
# Number of lines
#
# Number of words
#
# Number of characters
#
# and save it to the counter_of_string.txt file

# %%
from functools import reduce

with open("./sample_data/sample.txt","r") as file:
  string_list = file.readlines()

  # total line koita
  total_lines = len(string_list)

  # word ber korbo
  number_of_words = list(map(lambda x : len(x.split()),string_list))
  #total words
  total_number_of_words = reduce(lambda x,y : x+y ,number_of_words)

  #cleaning process

  # 1. new line delete
  string_list = list(map(str.strip,string_list))

  #2. space delete

  string_list = list(map(lambda x : x.replace(" ",""),string_list))

  # koita character

  number_of_character = list(map(lambda x : len(x),string_list))

  # total character
  total_number_of_characters = reduce(lambda x,y : x+y ,number_of_character)



with open("./sample_data/counter_of_string.txt","w") as file:
  file.write(f"total line: {total_lines}\ntotal number of words:{total_number_of_words}\ntotal number of char: {total_number_of_characters}")

# %% [markdown]
# ## Practice 2
# Write then read with one open

# %%
with open("./sample_data/write_read.txt","w+") as file:
  file.write("Hello world")

  print(file.tell())

  file.seek(0)
  print(file.tell())

  print(file.read())

  file.truncate(5)

  file.seek(0)

  print(file.read())
# Out:
# 11
# 0
# Hello world
# Hello

# %% [markdown]
# # Exception Handling

# %%
n = int(input())

try:
  a = 10/0
except ZeroDivisionError:
  print("you cant divide a number by 0")

print("hello world")
# Out:
# 20
# you cant divide a number by 0
# hello world

# %%
try:
  x = y
except ZeroDivisionError:
  print("you cant divide a number by 0")
except Exception as e:
  print(e)


print("hello world")
# Out:
# name 'y' is not defined
# hello world

# %%
# model train


try:
  file = open("./sample_data/data1.txt","r")
except Exception as e:
  print(e)
else:
  # model train
  print(file.read())
finally:
  print("Gpu is stopped")
# Out:
# [Errno 2] No such file or directory: './sample_data/data1.txt'
# Gpu is stopped
